# %% [markdown]
# Импортируем необходимые библиотеки

# %%
pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.0-cp310-cp310-win_amd64.whl (9.2 MB)
#      ---------------------------------------- 9.2/9.2 MB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (1.10.1)
# Requirement already satisfied: numpy>=1.18 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (1.23.5)
# Requirement already satisfied: packaging>=21.3 in c:\users\admin\appdata\roaming\python\python310\site-packages (from statsmodels) (23.1)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ------------------------------------- 233.8/233.8 KB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (2.0.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.0->statsmodels) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.0->statsmodels) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\appdata\roaming\python\python310\site-packages (from pandas>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: six in c:\users\admin\appdata\roaming\python\python310\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.3 statsmodels-0.14.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the 'c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.3-cp310-cp310-win_amd64.whl (569 kB)
#      -------------------------------------- 569.7/569.7 KB 1.9 MB/s eta 0:00:00
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29
#   Downloading Cython-3.0.0-cp310-cp310-win_amd64.whl (2.8 MB)
#      ---------------------------------------- 2.8/2.8 MB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from pmdarima) (1.26.15)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from pmdarima) (1.2.2)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from pmdarima) (1.23.5)
# Requirement already satisfied: joblib>=0.11 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from pmdarima) (1.10.1)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from pmdarima) (58.1.0)
# Requirement already satisfied: pandas>=0.19 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from pmdarima) (2.0.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\appdata\roaming\python\python310\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\admin\appdata\roaming\python\python310\site-packages (from statsmodels>=0.13.2->pmdarima) (23.1)
# Requirement already satisfied: six in c:\users\admin\appdata\roaming\python\python310\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Installing collected packages: Cython, pmdarima
# Successfully installed Cython-3.0.0 pmdarima-2.0.3
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the 'c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima import auto_arima

# %% [markdown]
# Решение задачи

# %%
# Загрузка данных файла AirPassengers.csv
data1 = pd.read_csv('AirPassengers.csv')
data1['Month'] = pd.to_datetime(data1['Month'], format='%Y-%m')
data1.set_index('Month', inplace=True)


# Визуализация данных файла AirPassengers.csv
data1['#Passengers'].plot(figsize=(12,5))
plt.title("Air Passengers")
plt.show()

# %%
# Загрузка данных aus_employment.csv
data2 = pd.read_csv('aus_employment.csv', parse_dates=['date'])
data2.set_index('date', inplace=True)

# Визуализация aus_employment.csv
data2['people_employed'].plot(figsize=(12,5))
plt.title("Australian Employment")
plt.show()

# %%
# Загрузка данных milk_production
data3 = pd.read_csv('milk_production.csv', usecols=[1,2], names=['date', 'production'], header=0)
data3['date'] = pd.to_datetime(data3['date'])
data3.set_index('date', inplace=True)

# Визуализация milk_production
data3['production'].plot(figsize=(12,5))
plt.title("Milk Production")
plt.show()

# %% [markdown]
# Примененим auto_arima для определения параметров SARIMA

# %%
# Функция для определения параметров SARIMA
def get_sarima_params(data):
    return auto_arima(data, seasonal=True, m=12, trace=True, error_action='ignore', suppress_warnings=True, stepwise=True)

# Параметры для каждого набора данных
params1 = get_sarima_params(data1['#Passengers'])
params2 = get_sarima_params(data2['people_employed'])
params3 = get_sarima_params(data3['production'])

print("Air Passengers SARIMA Params: ", params1.order, params1.seasonal_order)
print("Australian Employment SARIMA Params: ", params2.order, params2.seasonal_order)
print("Milk Production SARIMA Params: ", params3.order, params3.seasonal_order)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=1020.048, Time=0.56 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1031.508, Time=0.01 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1020.393, Time=0.06 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=1021.003, Time=0.08 sec
#  ARIMA(2,1,2)(0,1,1)[12]             : AIC=1019.935, Time=0.33 sec
#  ARIMA(2,1,2)(0,1,0)[12]             : AIC=1019.290, Time=0.11 sec
#  ARIMA(2,1,2)(1,1,0)[12]             : AIC=1019.546, Time=0.33 sec
#  ARIMA(1,1,2)(0,1,0)[12]             : AIC=1024.160, Time=0.06 sec
#  ARIMA(2,1,1)(0,1,0)[12]             : AIC=1017.847, Time=0.11 sec
#  ARIMA(2,1,1)(1,1,0)[12]             : AIC=1017.914, Time=0.28 sec
#  ARIMA(2,1,1)(0,1,1)[12]             : AIC=1018.359, Time=0.27 sec
#  ARIMA(2,1,1)(1,1,1)[12]             : AIC=1018.248, Time=0.56 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=1022.393, Time=0.04 sec
#  ARIMA(2,1,0)(0,1,0)[12]             : AIC=1022.393, Time=0.03 sec
#  ARIMA(3,1,1)(0,1,0)[12]             : AIC=1019.084, Time=0.11 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=1020.393, Time=0.02 sec
#  ARIMA(3,1,0)(0,1,0)[12]             : AIC=1023.666, Time=0.05 sec
#  ARIMA(3,1,2)(0,1,0)[12]             : AIC=1021.083, Time=0.20 sec
#  ARIMA(2,1,1)(0,1,0)[12] intercept   : AIC=inf, Time=0.26 sec
#
# Best model:  ARIMA(2,1,1)(0,1,0)[12]
# Total fit time: 3.508 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.55 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=1843.949, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=1621.646, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=1727.886, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=1844.871, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=1809.515, Time=0.03 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=inf, Time=0.56 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=1586.857, Time=0.32 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=1729.673, Time=0.13 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=inf, Time=0.81 sec
#  ARIMA(1,1,0)(1,0,2)[12] intercept   : AIC=1588.733, Time=0.68 sec
#  ARIMA(1,1,0)(0,0,2)[12] intercept   : AIC=1680.736, Time=0.36 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=1.04 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=1587.108, Time=0.25 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=1585.041, Time=0.43 sec
#  ARIMA(2,1,0)(0,0,1)[12] intercept   : AIC=1723.809, Time=0.18 sec
#  ARIMA(2,1,0)(1,0,0)[12] intercept   : AIC=1622.489, Time=0.21 sec
#  ARIMA(2,1,0)(2,0,1)[12] intercept   : AIC=inf, Time=0.91 sec
#  ARIMA(2,1,0)(1,0,2)[12] intercept   : AIC=1587.047, Time=0.79 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=1787.831, Time=0.05 sec
#  ARIMA(2,1,0)(0,0,2)[12] intercept   : AIC=1678.750, Time=0.36 sec
#  ARIMA(2,1,0)(2,0,0)[12] intercept   : AIC=inf, Time=0.57 sec
#  ARIMA(2,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=1.14 sec
#  ARIMA(3,1,0)(1,0,1)[12] intercept   : AIC=1577.707, Time=0.51 sec
#  ARIMA(3,1,0)(0,0,1)[12] intercept   : AIC=1720.940, Time=0.21 sec
#  ARIMA(3,1,0)(1,0,0)[12] intercept   : AIC=1615.685, Time=0.32 sec
#  ARIMA(3,1,0)(2,0,1)[12] intercept   : AIC=inf, Time=1.22 sec
#  ARIMA(3,1,0)(1,0,2)[12] intercept   : AIC=1579.531, Time=0.72 sec
#  ARIMA(3,1,0)(0,0,0)[12] intercept   : AIC=1788.731, Time=0.06 sec
#  ARIMA(3,1,0)(0,0,2)[12] intercept   : AIC=1675.160, Time=0.48 sec
#  ARIMA(3,1,0)(2,0,0)[12] intercept   : AIC=inf, Time=0.83 sec
#  ARIMA(3,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=1.19 sec
#  ARIMA(4,1,0)(1,0,1)[12] intercept   : AIC=1578.479, Time=0.67 sec
#  ARIMA(3,1,1)(1,0,1)[12] intercept   : AIC=1588.232, Time=0.57 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.52 sec
#  ARIMA(4,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.73 sec
#  ARIMA(3,1,0)(1,0,1)[12]             : AIC=1575.719, Time=0.30 sec
#  ARIMA(3,1,0)(0,0,1)[12]             : AIC=1723.111, Time=0.12 sec
#  ARIMA(3,1,0)(1,0,0)[12]             : AIC=1613.694, Time=0.18 sec
#  ARIMA(3,1,0)(2,0,1)[12]             : AIC=1577.547, Time=1.06 sec
#  ARIMA(3,1,0)(1,0,2)[12]             : AIC=1577.540, Time=0.49 sec
#  ARIMA(3,1,0)(0,0,0)[12]             : AIC=1798.598, Time=0.04 sec
#  ARIMA(3,1,0)(0,0,2)[12]             : AIC=1675.018, Time=0.31 sec
#  ARIMA(3,1,0)(2,0,0)[12]             : AIC=inf, Time=0.38 sec
#  ARIMA(3,1,0)(2,0,2)[12]             : AIC=1579.538, Time=0.67 sec
#  ARIMA(2,1,0)(1,0,1)[12]             : AIC=1583.106, Time=0.22 sec
#  ARIMA(4,1,0)(1,0,1)[12]             : AIC=1576.480, Time=0.35 sec
#  ARIMA(3,1,1)(1,0,1)[12]             : AIC=inf, Time=0.55 sec
#  ARIMA(2,1,1)(1,0,1)[12]             : AIC=inf, Time=0.34 sec
#  ARIMA(4,1,1)(1,0,1)[12]             : AIC=1574.956, Time=0.56 sec
#  ARIMA(4,1,1)(0,0,1)[12]             : AIC=1723.890, Time=0.48 sec
#  ARIMA(4,1,1)(1,0,0)[12]             : AIC=1614.924, Time=0.35 sec
#  ARIMA(4,1,1)(2,0,1)[12]             : AIC=inf, Time=nan sec
#  ARIMA(4,1,1)(1,0,2)[12]             : AIC=1576.720, Time=1.04 sec
#  ARIMA(4,1,1)(0,0,0)[12]             : AIC=1786.214, Time=0.09 sec
#  ARIMA(4,1,1)(0,0,2)[12]             : AIC=1671.720, Time=0.71 sec
#  ARIMA(4,1,1)(2,0,0)[12]             : AIC=inf, Time=1.06 sec
#  ARIMA(4,1,1)(2,0,2)[12]             : AIC=1578.725, Time=1.40 sec
#  ARIMA(5,1,1)(1,0,1)[12]             : AIC=inf, Time=0.69 sec
#  ARIMA(4,1,2)(1,0,1)[12]             : AIC=inf, Time=0.69 sec
#  ARIMA(3,1,2)(1,0,1)[12]             : AIC=inf, Time=0.64 sec
#  ARIMA(5,1,0)(1,0,1)[12]             : AIC=1576.655, Time=0.50 sec
#  ARIMA(5,1,2)(1,0,1)[12]             : AIC=inf, Time=1.06 sec
#
# Best model:  ARIMA(4,1,1)(1,0,1)[12]
# Total fit time: 33.184 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=1076.442, Time=0.70 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=1324.708, Time=0.02 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=1092.340, Time=0.15 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=1211.922, Time=0.17 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=1452.434, Time=0.01 sec
#  ARIMA(2,0,2)(0,1,1)[12] intercept   : AIC=1074.582, Time=0.45 sec
#  ARIMA(2,0,2)(0,1,0)[12] intercept   : AIC=1119.880, Time=0.17 sec
#  ARIMA(2,0,2)(0,1,2)[12] intercept   : AIC=1076.422, Time=1.27 sec
#  ARIMA(2,0,2)(1,1,0)[12] intercept   : AIC=1089.179, Time=0.46 sec
#  ARIMA(2,0,2)(1,1,2)[12] intercept   : AIC=inf, Time=2.03 sec
#  ARIMA(1,0,2)(0,1,1)[12] intercept   : AIC=1073.351, Time=0.33 sec
#  ARIMA(1,0,2)(0,1,0)[12] intercept   : AIC=1119.515, Time=0.11 sec
#  ARIMA(1,0,2)(1,1,1)[12] intercept   : AIC=1075.202, Time=0.50 sec
#  ARIMA(1,0,2)(0,1,2)[12] intercept   : AIC=1075.178, Time=0.79 sec
#  ARIMA(1,0,2)(1,1,0)[12] intercept   : AIC=1088.258, Time=0.30 sec
#  ARIMA(1,0,2)(1,1,2)[12] intercept   : AIC=inf, Time=1.91 sec
#  ARIMA(0,0,2)(0,1,1)[12] intercept   : AIC=1168.105, Time=0.29 sec
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=1072.433, Time=0.24 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=1119.187, Time=0.06 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=1074.309, Time=0.29 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=1074.286, Time=0.60 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=1088.480, Time=0.23 sec
#  ARIMA(1,0,1)(1,1,2)[12] intercept   : AIC=inf, Time=1.49 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=1075.731, Time=0.13 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=1074.053, Time=0.36 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=1324.948, Time=0.13 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=1072.066, Time=0.19 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=1118.785, Time=0.06 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=1073.928, Time=0.31 sec
#  ARIMA(2,0,0)(0,1,2)[12] intercept   : AIC=1073.904, Time=0.61 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=1087.735, Time=0.20 sec
#  ARIMA(2,0,0)(1,1,2)[12] intercept   : AIC=inf, Time=1.52 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=1074.033, Time=0.28 sec
#  ARIMA(3,0,1)(0,1,1)[12] intercept   : AIC=1072.806, Time=0.57 sec
#  ARIMA(2,0,0)(0,1,1)[12]             : AIC=1076.388, Time=0.18 sec
#
# Best model:  ARIMA(2,0,0)(0,1,1)[12] intercept
# Total fit time: 17.105 seconds
# Air Passengers SARIMA Params:  (2, 1, 1) (0, 1, 0, 12)
# Australian Employment SARIMA Params:  (4, 1, 1) (1, 0, 1, 12)
# Milk Production SARIMA Params:  (2, 0, 0) (0, 1, 1, 12)

# %% [markdown]
# Обучение модели SARIMA с найденными параметрами:

# %%
import matplotlib.pyplot as plt

# Прогнозирование на 12 месяцев вперед для каждой модели:
forecast1 = model1.get_forecast(steps=12)
forecast2 = model2.get_forecast(steps=12)
forecast3 = model3.get_forecast(steps=12)


# Визуализация прогноза для Air Passengers
plt.figure(figsize=(12,5))
plt.plot(data1.index, data1['#Passengers'], label='Historical Data')
plt.plot(pd.date_range(data1.index[-1], periods=12), forecast1.predicted_mean, color='red', label='Forecast')
plt.fill_between(pd.date_range(data1.index[-1], periods=12), forecast1.conf_int().iloc[:, 0], forecast1.conf_int().iloc[:, 1], color='pink', alpha=0.3)
plt.title("Air Passengers Forecast")
plt.legend()
plt.show()

# Визуализация прогноза для Australian Employment
plt.figure(figsize=(12,5))
plt.plot(data2.index, data2['people_employed'], label='Historical Data')
plt.plot(pd.date_range(data2.index[-1], periods=12), forecast2.predicted_mean, color='red', label='Forecast')
plt.fill_between(pd.date_range(data2.index[-1], periods=12), forecast2.conf_int().iloc[:, 0], forecast2.conf_int().iloc[:, 1], color='pink', alpha=0.3)
plt.title("Australian Employment Forecast")
plt.legend()
plt.show()

# Визуализация прогноза для Milk Production
plt.figure(figsize=(12,5))
plt.plot(data3.index, data3['production'], label='Historical Data')
plt.plot(pd.date_range(data3.index[-1], periods=12), forecast3.predicted_mean, color='red', label='Forecast')
plt.fill_between(pd.date_range(data3.index[-1], periods=12), forecast3.conf_int().iloc[:, 0], forecast3.conf_int().iloc[:, 1], color='pink', alpha=0.3)
plt.title("Milk Production Forecast")
plt.legend()
plt.show()
